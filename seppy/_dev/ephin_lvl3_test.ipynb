# %%
import os
import datetime as dt

from seppy.loader.soho import soho_load, soho_ephin_l3_download, soho_ephin_l3_loader
# Out:
# WARNING: Breaking changes in SEPpy v0.4.0: The metadata for SOHO/EPHIN, SOHO/ERNE, STEREO/SEPT, and Wind/3DP have changed! See https://github.com/serpentine-h2020/SEPpy/releases/tag/v0.4.0 for details. (You can ignore this if you do not invoke SEPpy manually.)

# %%
dataset="SOHO_COSTEP-EPHIN_L3E-1MIN"
startdate=dt.datetime(2021, 10, 28)
enddate="2021/10/30"
path= f"{os.getcwd()}{os.sep}data"
resample=None
pos_timestamp=None


df, meta = soho_load(dataset=dataset, startdate=startdate, enddate=enddate,
                     path=path, resample=resample, pos_timestamp=pos_timestamp)
# Out:
# :D

# %%
meta
# Out:
# {'energy_labels': {'E0': 0.299,
#   'E1': 0.328,
#   'E2': 0.372,
#   'E3': 0.421,
#   'E4': 0.473,
#   'E5': 0.53,
#   'E6': 0.587,
#   'E7': 0.643,
#   'E8': 0.703,
#   'E9': 0.761,
#   'E10': 0.821,
#   'E11': 0.881,
#   'E12': 0.969,
#   'E13': 1.104,
#   'E14': 1.241}}

# %%
df
# Out:
#                             E0         E1         E2         E3         E4  \
# time
# 2021-10-28 00:01:12   0.045471   0.034752   0.000000   0.000000   0.000000
# 2021-10-28 00:09:11   0.090958   0.034759   0.030578   0.030670   0.000000
# 2021-10-28 00:17:11   0.000000   0.000000   0.000000   0.000000   0.000000
# 2021-10-28 00:25:11   0.090942   0.000000   0.030573   0.030665   0.035386
# 2021-10-28 00:33:10   0.000000   0.034755   0.061149   0.000000   0.000000
# ...                        ...        ...        ...        ...        ...
# 2021-10-30 23:17:51  61.162039  47.939083  41.873016  33.719725  24.406146
# 2021-10-30 23:25:51  62.345474  53.584317  41.619941  35.386236  22.963693
# 2021-10-30 23:33:50  60.564710  50.173863  44.436405  32.868682  22.103634
# 2021-10-30 23:41:50  59.656002  51.504151  43.675347  37.250749  23.985903
# 2021-10-30 23:49:50  55.450071  50.351683  43.704996  32.951513  21.960152
#
#                             E5         E6         E7         E8        E9  \
# time
# 2021-10-28 00:01:12   0.000000   0.060215   0.000000   0.000000  0.000000
# 2021-10-28 00:09:11   0.000000   0.000000   0.000000   0.000000  0.000000
# 2021-10-28 00:17:11   0.000000   0.060216   0.000000   0.000000  0.000000
# 2021-10-28 00:25:11   0.000000   0.000000   0.000000   0.000000  0.000000
# 2021-10-28 00:33:10   0.000000   0.060219   0.000000   0.000000  0.000000
# ...                        ...        ...        ...        ...       ...
# 2021-10-30 23:17:51  21.858746  17.735985  11.752815   9.242609  6.984970
# 2021-10-30 23:25:51  20.525665  16.894258  12.091670  10.372135  6.508832
# 2021-10-30 23:33:50  18.490931  17.123700  15.517378  10.923764  8.645941
# 2021-10-30 23:41:50  19.353127  14.922213  15.715087   8.558347  6.481788
# 2021-10-30 23:49:50  17.614451  17.884982  15.010948   7.919650  6.442363
#
#                      ...  E8_err_stat  E9_err_stat  E10_err_stat  \
# time                 ...
# 2021-10-28 00:01:12  ...     0.000000     0.000000      0.000000
# 2021-10-28 00:09:11  ...     0.000000     0.000000      0.000000
# 2021-10-28 00:17:11  ...     0.000000     0.000000      0.000000
# 2021-10-28 00:25:11  ...     0.000000     0.000000      0.000000
# 2021-10-28 00:33:10  ...     0.000000     0.000000      0.000000
# ...                  ...          ...          ...           ...
# 2021-10-30 23:17:51  ...     1.675678     1.754762      2.479277
# 2021-10-30 23:25:51  ...     1.772094     1.688355      2.625193
# 2021-10-30 23:33:50  ...     1.816451     1.945307      2.536590
# 2021-10-30 23:41:50  ...     1.603559     1.681404      2.000815
# 2021-10-30 23:49:50  ...     1.537079     1.671272      2.520287
#
#                      E11_err_stat  E12_err_stat  E13_err_stat  E14_err_stat  \
# time
# 2021-10-28 00:01:12      0.000000      0.000000      0.000000      0.000000
# 2021-10-28 00:09:11      0.000000      0.000000      0.000000      0.000000
# 2021-10-28 00:17:11      0.000000      0.000000      0.000000      0.000000
# 2021-10-28 00:25:11      0.000000      0.000000      0.000000      0.000000
# 2021-10-28 00:33:10      0.000000      0.000000      0.000000      0.000000
# ...                           ...           ...           ...           ...
# 2021-10-30 23:17:51      2.138456      1.944654      3.250341      0.000000
# 2021-10-30 23:25:51      2.329164      2.118079      4.173433      5.147995
# 2021-10-30 23:33:50      2.844634      2.438134      2.627203      7.257647
# 2021-10-30 23:41:50      2.506149      1.216296      4.920676      5.126631
# 2021-10-30 23:49:50      3.126523      2.843176      3.197801      5.095488
#
#                      ring_off  scale_factor  contam
# time
# 2021-10-28 00:01:12       0.0      1.001279      14
# 2021-10-28 00:09:11       0.0      1.001464      14
# 2021-10-28 00:17:11       0.0      1.001307      14
# 2021-10-28 00:25:11       0.0      1.001293      14
# 2021-10-28 00:33:10       0.0      1.001350      14
# ...                       ...           ...     ...
# 2021-10-30 23:17:51       0.0      2.457687      11
# 2021-10-30 23:25:51       0.0      2.442833      11
# 2021-10-30 23:33:50       0.0      2.433684      11
# 2021-10-30 23:41:50       0.0      2.432683      11
# 2021-10-30 23:49:50       0.0      2.417886      11
#
# [510 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['E0', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10',
#        'E11', 'E12', 'E13', 'E14', 'E0_err_syst', 'E1_err_syst', 'E2_err_syst',
#        'E3_err_syst', 'E4_err_syst', 'E5_err_syst', 'E6_err_syst',
#        'E7_err_syst', 'E8_err_syst', 'E9_err_syst', 'E10_err_syst',
#        'E11_err_syst', 'E12_err_syst', 'E13_err_syst', 'E14_err_syst',
#        'E0_err_stat', 'E1_err_stat', 'E2_err_stat', 'E3_err_stat',
#        'E4_err_stat', 'E5_err_stat', 'E6_err_stat', 'E7_err_stat',
#        'E8_err_stat', 'E9_err_stat', 'E10_err_stat', 'E11_err_stat',
#        'E12_err_stat', 'E13_err_stat', 'E14_err_stat', 'ring_off',
#        'scale_factor', 'contam'],
#       dtype='str')
